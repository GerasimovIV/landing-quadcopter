# %%
import numpy as np
import cv2 as cv
cap = cv.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()
while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    # if frame is read correctly ret is True
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    # Our operations on the frame come here
    gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    # Display the resulting frame
    cv.imshow('frame', gray)
    if cv.waitKey(1) == ord('q'):
        break
# When everything done, release the capture
cap.release()
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv
cap0 = cv.VideoCapture(0)
cap1 = cv.VideoCapture(1)
if not cap0.isOpened():
    print("Cannot open camera")
    exit()
if not cap1.isOpened():
    print("Cannot open camera")
    exit()
while True:
    # Capture frame-by-frame
    ret0, frame0 = cap0.read()
    # if frame is read correctly ret is True
    if not ret0:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    ret1, frame1 = cap1.read()
    # if frame is read correctly ret is True
    if not ret1:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    # Our operations on the frame come here
    gray = cv.cvtColor(frame0, cv.COLOR_BGR2GRAY)
    # Display the resulting frame
    cv.imshow('frame0', gray)
    cv.imshow('frame1', color)
    if cv.waitKey(1) == ord('q'):
        break
# When everything done, release the capture
cap0.release()
cap1.release()
cv.destroyAllWindows()

# %%
from ximea import xiapi
import PIL
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont
import urllib.request
import matplotlib.pyplot as plt

#create instance for first connected camera
cam = xiapi.Camera(0)
cam1 = xiapi.Camera(1)

#start communication
#to open specific device, use:
#cam.open_device_by_SN('41305651')
#(open by serial number)
print('Opening first camera...')
cam.open_device()
print('Opening second camera...')
cam1.open_device()

#settings
cam.set_exposure(10000)
print('Exposure was set to %i us' %cam.get_exposure())
cam1.set_exposure(10000)
print('Exposure was set to %i us' %cam.get_exposure())

#create instance of Image to store image data and metadata
img = xiapi.Image()
img1 = xiapi.Image()

#start data acquisition
print('Starting data acquisition...')
cam.start_acquisition()
print('Starting data acquisition...')
cam1.start_acquisition()

for i in range(10):
    #get data and pass them from camera to img
    cam.get_image(img)
    

    #get raw data from camera
    #for Python2.x function returns string
    #for Python3.x function returns bytes
    data_raw = img.get_image_data_raw()
    
    #print(type(data_raw))
    #transform data to list
    data = list(data_raw)
    
    #plt.imshow(data)
    #plt.show()
    #print image data and metadata
    print('Image number: ' + str(i))
    print('Camera number: ' + str(0))
    #print('Image width (pixels):  ' + str(img.width))
    #print('Image height (pixels): ' + str(img.height))
    #print('First 10 pixels: ' + str(data[:10]))
    a = img.get_image_data_numpy()
    #print(a)
    plt.imshow(a)
    plt.show()
    
    
    
    cam1.get_image(img1)
    data_raw1 = img1.get_image_data_raw()
    data1 = list(data_raw1)
    print('Image number: ' + str(i))
    print('Camera number: ' + str(1))
    a1 = img1.get_image_data_numpy()
    #print(a)
    plt.imshow(a1)
    plt.show()
    #np.save("image" + str(i) + ".JPG", a)
    print('\n')    
    

#stop data acquisition
print('Stopping acquisition...')
cam.stop_acquisition()

#stop communication
cam.close_device()

print('Done.')
# Out:
# Opening first camera...
# Opening second camera...
# Exposure was set to 9904 us
# Exposure was set to 9904 us
# Starting data acquisition...
# Starting data acquisition...
# ---------------------------------------------------------------------------
# Xi_error                                  Traceback (most recent call last)
# <ipython-input-25-1b203b1062a3> in <module>()
#      38 for i in range(10):
#      39     #get data and pass them from camera to img
# ---> 40     cam.get_image(img)
#      41
#      42
#
# /usr/lib/python3/dist-packages/ximea/xiapi.py in get_image(self, image, timeout)
#     316
#     317         if not stat == 0:
# --> 318             raise Xi_error(stat)
#     319
#     320
#
# Xi_error: ERROR 10: Timeout

# %%
#stop data acquisition
print('Stopping acquisition...')
cam.stop_acquisition()
cam1.stop_acquisition()

#stop communication
cam.close_device()
cam1.close_device()

print('Done.')
# Out:
# Stopping acquisition...
# Done.

# %%
from ximea import xiapi

#create instance for first connected camera
cam = xiapi.Camera(0)

#start communication
#to open specific device, use:
#cam.open_device_by_SN('41305651')
#(open by serial number)
print('Opening first camera...')
cam.open_device()

#settings
cam.set_exposure(10000)
print('Exposure was set to %i us' %cam.get_exposure())

#create instance of Image to store image data and metadata
img = xiapi.Image()

#start data acquisition
print('Starting data acquisition...')
cam.start_acquisition()

for i in range(1):
    #get data and pass them from camera to img
    cam.get_image(img)

    #print image data and metadata
    print('Image number: ' + str(i))
    print('Image width (pixels):  ' + str(img.width))
    print('Image height (pixels): ' + str(img.height))
    print('\n')    
    pl = img.get_image_data_numpy()
    plt.imshow(pl)
    plt.show()
#stop data acquisition
print('Stopping acquisition...')
cam.stop_acquisition()

#stop communication
cam.close_device()

print('Done.')
# Out:
# Opening first camera...
# Exposure was set to 9904 us
# Starting data acquisition...
# Image number: 0
# Image width (pixels):  2592
# Image height (pixels): 1944
# Stopping acquisition...
# Done.

# %%
from ximea import xiapi

#create instance for first connected camera
cam = xiapi.Camera(1)

#start communication
#to open specific device, use:
#cam.open_device_by_SN('41305651')
#(open by serial number)
print('Opening first camera...')
cam.open_device()

#settings
cam.set_exposure(10000)
print('Exposure was set to %i us' %cam.get_exposure())

#create instance of Image to store image data and metadata
img = xiapi.Image()

#start data acquisition
print('Starting data acquisition...')
cam.start_acquisition()

for i in range(1):
    #get data and pass them from camera to img
    cam.get_image(img)

    #print image data and metadata
    print('Image number: ' + str(i))
    print('Image width (pixels):  ' + str(img.width))
    print('Image height (pixels): ' + str(img.height))
    print('\n')    
    pl = img.get_image_data_numpy()
    plt.imshow(pl)
    plt.show()
    print(img.get_image_data_raw())
#stop data acquisition
print('Stopping acquisition...')
cam.stop_acquisition()

#stop communication
cam.close_device()

print('Done.')
# Out:
# Opening first camera...
# Exposure was set to 9904 us
# Starting data acquisition...
# Image number: 0
# Image width (pixels):  2592
# Image height (pixels): 1944
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
new_im = Image.fromarray(pl)
new_im.save("numpy_altered_sample2.png")

# %%
import cv2
cv2.imwrite('pl.jpg', pl)
# Out:
# True

# %%
import scipy.imag
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-50-e438d657380b> in <module>()
# ----> 1 import scipy.imag
#
# ModuleNotFoundError: No module named 'scipy.imag'
